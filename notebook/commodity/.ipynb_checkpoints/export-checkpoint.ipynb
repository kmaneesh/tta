# %% [markdown]
# # Initialisation

# %%
import os
import sys
sys.path.append("../../..") 
ROOT_DIR = '/home/jovyan/tta'

import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 5000)

from comtrade.analysis import Analysis
tta = Analysis()

# %% [markdown]
# # Codes

# %%
# Code for india as reporter and partner
india = 699 
# Trade regime
# [{'id': '1', 'text': 'Import'}, {'id': '2', 'text': 'Export'}, 
# {'id': '3', 'text': 're-Export'}, {'id': '4', 'text': 're-Import'}]
# Chapter
cc = 710813

# %% [markdown]
# # Data Available

# %%
source = 699 # India
destination = 'ALL' # all
tta.set_source_destination(source, destination)

status = tta.api.data_available(india, 2019, 'HS', 'Y')
print(status)
# Out:
# []

# %% [markdown]
# ## Data request

# %%
data_out, data_in = tta.get_export_data(2019, cc)
# Out:
# {'r': 699, 'p': 'ALL', 'rg': 2, 'ps': 2019, 'px': 'HS', 'cc': 710813, 'freq': 'A', 'max': '100000'}
# {'r': 'ALL', 'p': 699, 'rg': 1, 'ps': 2019, 'px': 'HS', 'cc': 710813, 'freq': 'A', 'max': '100000'}

# %%
data = tta.compare(data_out, data_in, 'pt3ISO', 'rt3ISO')

# %% [markdown]
# ## Data

# %%
df = pd.DataFrame.from_dict(data, orient='index')
df['value_diff'] = df['value_a'] - df['value_b']
df['quantity_diff'] = df['quantity_a'] - df['quantity_b']
df['quantity_diff'].round(2)
df['value_diff'].round(2)
df['quantity_pct'] = (df['quantity_diff'] / df['quantity_a']) * 100
df['value_pct'] = (df['value_diff'] / df['value_a']) * 100
df['quantity_pct'].round(2)
df['value_pct'].round(2)
df['value_diff_abs'] = abs(df['value_diff'])
df['value_pct_abs'] = abs(df['value_pct'])
df['iso'] = df.index
df
# Out:
#        code                             desc  quantity_a      quantity_desc_a  \
# WLD  710813  Metals; gold, semi-manufactured         156  Weight in kilograms
# DEU  710813  Metals; gold, semi-manufactured           1  Weight in kilograms
# IDN  710813  Metals; gold, semi-manufactured           0  Weight in kilograms
# KOR  710813  Metals; gold, semi-manufactured           0  Weight in kilograms
# ARE  710813  Metals; gold, semi-manufactured         155  Weight in kilograms
# USA  710813  Metals; gold, semi-manufactured           0  Weight in kilograms
# AUS  710813  Metals; gold, semi-manufactured           0  Weight in kilograms
# AUT  710813  Metals; gold, semi-manufactured           0  Weight in kilograms
# CAN  710813  Metals; gold, semi-manufactured           0  Weight in kilograms
# DNK  710813  Metals; gold, semi-manufactured           0  Weight in kilograms
# HKG  710813  Metals; gold, semi-manufactured           0  Weight in kilograms
# ISL  710813  Metals; gold, semi-manufactured           0  Weight in kilograms
# MYS  710813  Metals; gold, semi-manufactured           0  Weight in kilograms
# SGP  710813  Metals; gold, semi-manufactured           0  Weight in kilograms
# ZAF  710813  Metals; gold, semi-manufactured           0  Weight in kilograms
# CHE  710813  Metals; gold, semi-manufactured           0  Weight in kilograms
# THA  710813  Metals; gold, semi-manufactured           0  Weight in kilograms
#
#      value_a  quantity_b      quantity_desc_b  value_b  value_diff  \
# WLD     6.30           0  Weight in kilograms     0.00        6.30
# DEU     0.03           1  Weight in kilograms     0.03        0.00
# IDN     0.00           0  Weight in kilograms     0.00        0.00
# KOR     0.00           0  Weight in kilograms     0.01       -0.01
# ARE     6.26           0  Weight in kilograms     0.00        6.26
# USA     0.00           0  Weight in kilograms     0.00        0.00
# AUS     0.00           6  Weight in kilograms     0.28       -0.28
# AUT     0.00           0  Weight in kilograms     0.00        0.00
# CAN     0.00           0  Weight in kilograms     0.02       -0.02
# DNK     0.00           1  Weight in kilograms     0.00        0.00
# HKG     0.00       11664  Weight in kilograms   477.18     -477.18
# ISL     0.00           1  Weight in kilograms     0.00        0.00
# MYS     0.00          15  Weight in kilograms     0.48       -0.48
# SGP     0.00           4  Weight in kilograms     0.20       -0.20
# ZAF     0.00           0  Weight in kilograms     0.00        0.00
# CHE     0.00           0  Weight in kilograms     0.00        0.00
# THA     0.00           0  Weight in kilograms     0.04       -0.04
#
#      quantity_diff  quantity_pct  value_pct  value_diff_abs  value_pct_abs  \
# WLD            156         100.0      100.0            6.30          100.0
# DEU              0           0.0        0.0            0.00            0.0
# IDN              0           NaN        NaN            0.00            NaN
# KOR              0           NaN       -inf            0.01            inf
# ARE            155         100.0      100.0            6.26          100.0
# USA              0           NaN        NaN            0.00            NaN
# AUS             -6          -inf       -inf            0.28            inf
# AUT              0           NaN        NaN            0.00            NaN
# CAN              0           NaN       -inf            0.02            inf
# DNK             -1          -inf        NaN            0.00            NaN
# HKG         -11664          -inf       -inf          477.18            inf
# ISL             -1          -inf        NaN            0.00            NaN
# MYS            -15          -inf       -inf            0.48            inf
# SGP             -4          -inf       -inf            0.20            inf
# ZAF              0           NaN        NaN            0.00            NaN
# CHE              0           NaN        NaN            0.00            NaN
# THA              0           NaN       -inf            0.04            inf
#
#      iso
# WLD  WLD
# DEU  DEU
# IDN  IDN
# KOR  KOR
# ARE  ARE
# USA  USA
# AUS  AUS
# AUT  AUT
# CAN  CAN
# DNK  DNK
# HKG  HKG
# ISL  ISL
# MYS  MYS
# SGP  SGP
# ZAF  ZAF
# CHE  CHE
# THA  THA

# %%
df.plot(kind='bar', y=['value_a','value_b'], x='iso')
plt.show()

# %% [markdown]
# ## Aggregate

# %%
print("Total Export, as per Source data:", df['value_a'].sum(), " million USD.")
print("Total Import, as per Destination data:", df['value_b'].sum(), " million USD.")
# Out:
# Total Export, as per Source data: 12.59  million USD.
# Total Import, as per Destination data: 478.24  million USD.

# %% [markdown]
# ## Filter
# Remove data where the value difference is less than 10 million and percentage difference is less than 10%

# %%
percentage_cutoff = 10 # value to filter
value_diff_cutoff = 10 # value to filter
dfi = df[(df['value_pct_abs'] > percentage_cutoff) & (df['value_diff_abs'] > value_diff_cutoff)]
dfi.sort_values(by=['value_diff_abs'])
# Out:
#        code                             desc  quantity_a      quantity_desc_a  \
# HKG  710813  Metals; gold, semi-manufactured           0  Weight in kilograms
#
#      value_a  quantity_b      quantity_desc_b  value_b  value_diff  \
# HKG      0.0       11664  Weight in kilograms   477.18     -477.18
#
#      quantity_diff  quantity_pct  value_pct  value_diff_abs  value_pct_abs  \
# HKG         -11664          -inf       -inf          477.18            inf
#
#      iso
# HKG  HKG

# %%
df.plot(kind='bar', y=['value_a','value_b'], x='iso')
plt.show()
