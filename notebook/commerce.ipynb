# %% [markdown]
# # Settings & Initialisation

# %%
import os
import sys
sys.path.append("..") 
ROOT_DIR = '/home/jovyan/tta'
from IPython.core.display import display, HTML
from web.india.commerce import Commerce
api = Commerce()

# %%
api.get_country_code("JAPAN")
# Out:
# '205'

# %%
import warnings
warnings.filterwarnings('ignore')
data = api.get_calendar_year_data(205, 2019, 2)

# %%
data
# Out:
# {'03': {'hscode': '03',
#   'description': 'FISH AND CRUSTACEANS, MOLLUSCS AND OTHER AQUATIC INVERTABRATES.',
#   'pvalue': 410.14,
#   'value': 418.89},
#  '04': {'hscode': '04',
#   'description': "DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDIBLE PROD. OF ANIMAL ORIGIN, NOT ELSEWHERE SPEC. OR INCLUDED.",
#   'pvalue': 8.68,
#   'value': 5.1499999999999995},
#  '05': {'hscode': '05',
#   'description': 'PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE SPECIFIED OR INCLUDED.',
#   'pvalue': 8.39,
#   'value': 8.51},
#  '06': {'hscode': '06',
#   'description': 'LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND THE LIKE; CUT FLOWERS AND ORNAMENTAL FOLIAGE.',
#   'pvalue': 2.14,
#   'value': 2.1400000000000006},
#  '07': {'hscode': '07',
#   'description': 'EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.',
#   'pvalue': 3.69,
#   'value': 4.67},
#  '08': {'hscode': '08',
#   'description': 'EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR MELONS.',
#   'pvalue': 85.26,
#   'value': 69.06},
#  '09': {'hscode': '09',
#   'description': 'COFFEE, TEA, MATE AND SPICES.',
#   'pvalue': 37.36,
#   'value': 44.059999999999995},
#  '10': {'hscode': '10',
#   'description': 'CEREALS.',
#   'pvalue': 5.07,
#   'value': 5.449999999999999},
#  '11': {'hscode': '11',
#   'description': 'PRODUCTS OF THE MILLING INDUSTRY; MALT; STARCHES; INULIN; WHEAT GLUTEN.',
#   'pvalue': 1.9100000000000001,
#   'value': 2.52},
#  '12': {'hscode': '12',
#   'description': 'OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEEDS AND FRUIT; INDUSTRIAL OR MEDICINAL PLANTS; STRAW AND FODDER.',
#   'pvalue': 10.27,
#   'value': 10.1},
#  '13': {'hscode': '13',
#   'description': 'LAC; GUMS, RESINS AND OTHER VEGETABLE SAPS AND EXTRACTS.',
#   'pvalue': 31.710000000000004,
#   'value': 24.299999999999997},
#  '14': {'hscode': '14',
#   'description': 'VEGETABLE PLAITING MATERIALS; VEGETABLE PRODUCTS NOT ELSEWHERE SPECIFIED OR INCLUDED.',
#   'pvalue': 8.799999999999999,
#   'value': 8.37},
#  '15': {'hscode': '15',
#   'description': 'ANIMAL OR VEGETABLE FATS AND OILS AND THEIR CLEAVAGE PRODUCTS; PRE. EDIBLE FATS; ANIMAL OR VEGETABLE WAXEX.',
#   'pvalue': 45.379999999999995,
#   'value': 43.849999999999994},
#  '16': {'hscode': '16',
#   'description': 'PREPARATIONS OF MEAT, OF FISH OR OF CRUSTACEANS, MOLLUSCS OR OTHER AQUATIC INVERTEBRATES',
#   'pvalue': 4.210000000000001,
#   'value': 6.33},
#  '17': {'hscode': '17',
#   'description': 'SUGARS AND SUGAR CONFECTIONERY.',
#   'pvalue': 0.12000000000000001,
#   'value': 0.09},
#  '18': {'hscode': '18',
#   'description': 'COCOA AND COCOA PREPARATIONS.',
#   'pvalue': 0.03,
#   'value': 0.02},
#  '19': {'hscode': '19',
#   'description': 'PREPARATIONS OF CEREALS, FLOUR, STARCH OR MILK; PASTRYCOOKS PRODUCTS.',
#   'pvalue': 0.8,
#   'value': 1.0399999999999998},
#  '20': {'hscode': '20',
#   'description': 'PREPARATIONS OF VEGETABLES, FRUIT, NUTS OR OTHER PARTS OF PLANTS.',
#   'pvalue': 9.740000000000002,
#   'value': 9.25},
#  '21': {'hscode': '21',
#   'description': 'MISCELLANEOUS EDIBLE PREPARATIONS.',
#   'pvalue': 9.13,
#   'value': 9.27},
#  '22': {'hscode': '22',
#   'description': 'BEVERAGES, SPIRITS AND VINEGAR.',
#   'pvalue': 1.22,
#   'value': 0.9500000000000002},
#  '23': {'hscode': '23',
#   'description': 'RESIDUES AND WASTE FROM THE FOOD INDUSTRIES; PREPARED ANIMAL FODER.',
#   'pvalue': 75.05000000000001,
#   'value': 43.46},
#  '24': {'hscode': '24',
#   'description': 'TOBACCO AND MANUFACTURED TOBACCO SUBSTITUTES.',
#   'pvalue': 0.09,
#   'value': 0.97},
#  '25': {'hscode': '25',
#   'description': 'SALT; SULPHUR; EARTHS AND STONE; PLASTERING MATERIALS, LIME AND CEMENT.',
#   'pvalue': 35.730000000000004,
#   'value': 40.71},
#  '26': {'hscode': '26',
#   'description': 'ORES, SLAG AND ASH.',
#   'pvalue': 151.23000000000002,
#   'value': 209.82000000000002},
#  '27': {'hscode': '27',
#   'description': 'MINERAL FUELS, MINERAL OILS AND PRODUCTS OF THEIR DISTILLATION; BITUMINOUS SUBSTANCES; MINERAL WAXES.',
#   'pvalue': 538.1799999999998,
#   'value': 579.25},
#  '28': {'hscode': '28',
#   'description': 'INORGANIC CHEMICALS; ORGANIC OR INORGANIC COMPOUNDS OF PRECIOUS METALS, OF RARE-EARTH METALS, OR RADI. ELEM. OR OF ISOTOPES.',
#   'pvalue': 53.059999999999995,
#   'value': 76.69},
#  '29': {'hscode': '29',
#   'description': 'ORGANIC CHEMICALS',
#   'pvalue': 477.18999999999994,
#   'value': 572.34},
#  '30': {'hscode': '30',
#   'description': 'PHARMACEUTICAL PRODUCTS',
#   'pvalue': 49.62,
#   'value': 64.17999999999999},
#  '31': {'hscode': '31',
#   'description': 'FERTILISERS.',
#   'pvalue': 0.24,
#   'value': 0.09},
#  '32': {'hscode': '32',
#   'description': 'TANNING OR DYEING EXTRACTS; TANNINS AND THEIR DERI. DYES, PIGMENTS AND OTHER COLOURING MATTER; PAINTS AND VER; PUTTY AND OTHER MASTICS; INKS.',
#   'pvalue': 78.83,
#   'value': 87.8},
#  '33': {'hscode': '33',
#   'description': 'ESSENTIAL OILS AND RESINOIDS; PERFUMERY, COSMETIC OR TOILET PREPARATIONS.',
#   'pvalue': 32.16,
#   'value': 30.82},
#  '34': {'hscode': '34',
#   'description': 'SOAP, ORGANIC SURFACE-ACTIVE AGENTS, WASHING PREPARATIONS, LUBRICATING PREPARATIONS, ARTIFICIAL WAXES, PREPARED WAXES, POLISHING OR SCOURING PREP.',
#   'pvalue': 1.93,
#   'value': 1.5800000000000003},
#  '35': {'hscode': '35',
#   'description': 'ALBUMINOIDAL SUBSTANCES; MODIFIED STARCHES; GLUES; ENZYMES.',
#   'pvalue': 18.520000000000003,
#   'value': 15.06},
#  '37': {'hscode': '37',
#   'description': 'PHOTOGRAPHIC OR CINEMATOGRAPHIC GOODS.',
#   'pvalue': 0.08,
#   'value': 0.03},
#  '38': {'hscode': '38',
#   'description': 'MISCELLANEOUS CHEMICAL PRODUCTS.',
#   'pvalue': 130.04,
#   'value': 141.13},
#  '39': {'hscode': '39',
#   'description': 'PLASTIC AND ARTICLES THEREOF.',
#   'pvalue': 131.76,
#   'value': 112.80999999999997},
#  '40': {'hscode': '40',
#   'description': 'RUBBER AND ARTICLES THEREOF.',
#   'pvalue': 23.729999999999997,
#   'value': 26.419999999999995},
#  '41': {'hscode': '41',
#   'description': 'RAW HIDES AND SKINS (OTHER THAN FURSKINS) AND LEATHER',
#   'pvalue': 3.9499999999999997,
#   'value': 3.31},
#  '42': {'hscode': '42',
#   'description': 'ARTICLES OF LEATHER,SADDLERY AND HARNESS;TRAVEL GOODS, HANDBAGS AND SIMILAR CONT.ARTICLES OF ANIMAL GUT(OTHR THN SILK-WRM)GUT.',
#   'pvalue': 37.86,
#   'value': 39.269999999999996},
#  '43': {'hscode': '43',
#   'description': 'FURSKINS AND ARTIFICIAL FUR, MANUFACTURES THEREOF.',
#   'pvalue': 0.01,
#   'value': 0.05},
#  '44': {'hscode': '44',
#   'description': 'WOOD AND ARTICLES OF WOOD; WOOD CHARCOAL.',
#   'pvalue': 2.12,
#   'value': 1.58},
#  '45': {'hscode': '45',
#   'description': 'CORK AND ARTICLES OF CORK.',
#   'pvalue': 0,
#   'value': 0},
#  '46': {'hscode': '46',
#   'description': 'MANUFACTURES OF STRAW, OF ESPARTO OR OF OTHER PLAITING MATERIALS; BASKETWARE AND WICKERWORK.',
#   'pvalue': 0.04,
#   'value': 0.13},
#  '47': {'hscode': '47',
#   'description': 'PULP OF WOOD OR OF OTHER FIBROUS CELLULOSIC MATERIAL; WASTE AND SCRAP OF PAPER OR PAPERBOARD.',
#   'pvalue': 0,
#   'value': 0},
#  '48': {'hscode': '48',
#   'description': 'PAPER AND PAPERBOARD; ARTICLES OF PAPER PULP, OF PAPER OR OF PAPERBOARD.',
#   'pvalue': 0.7899999999999999,
#   'value': 0.8},
#  '49': {'hscode': '49',
#   'description': 'PRINTED BOOKDS, NEWSPAPERS, PICTURES AND OTHER PRODUCTS OF THE PRINTING INDUSTRY; MANUSCRIPTS, TYPESCRIPTS AND PLANS.',
#   'pvalue': 0.56,
#   'value': 0.44000000000000006},
#  '50': {'hscode': '50',
#   'description': 'SILK',
#   'pvalue': 1.11,
#   'value': 0.7200000000000001},
#  '51': {'hscode': '51',
#   'description': 'WOOL, FINE OR COARSE ANIMAL HAIR, HORSEHAIR YARN AND WOVEN FABRIC.',
#   'pvalue': 25.919999999999998,
#   'value': 24.869999999999994},
#  '52': {'hscode': '52',
#   'description': 'COTTON.',
#   'pvalue': 64.53,
#   'value': 55.949999999999996},
#  '53': {'hscode': '53',
#   'description': 'OTHER VEGETABLE TEXTILE FIBRES; PAPER YARN AND WOVEN FABRICS OF PAPER YARN.',
#   'pvalue': 5.22,
#   'value': 5.379999999999999},
#  '54': {'hscode': '54',
#   'description': 'MAN-MADE FILAMENTS.',
#   'pvalue': 11.569999999999999,
#   'value': 9.540000000000001},
#  '55': {'hscode': '55',
#   'description': 'MAN-MADE STAPLE FIBRES.',
#   'pvalue': 12.96,
#   'value': 10.930000000000001},
#  '56': {'hscode': '56',
#   'description': 'WADDING, FELT AND NONWOVENS; SPACIAL YARNS; TWINE, CORDAGE, ROPES AND CABLES AND ARTICLES THEREOF.',
#   'pvalue': 2.91,
#   'value': 2.79},
#  '57': {'hscode': '57',
#   'description': 'CARPETS AND OTHER TEXTILE FLOOR COVERINGS.',
#   'pvalue': 20.040000000000003,
#   'value': 20.14},
#  '58': {'hscode': '58',
#   'description': 'SPECIAL WOVEN FABRICS; TUFTED TEXTILE FABRICS; LACE; TAPESTRIES; TRIMMINGS; EMBROIDERY.',
#   'pvalue': 1.6400000000000001,
#   'value': 1.53},
#  '59': {'hscode': '59',
#   'description': 'IMPREGNATED, COATED, COVERED OR LAMINATED TEXTILE FABRICS; TEXTILE ARTICLES OF A KIND SUITABLE FOR INDUSTRIAL USE.',
#   'pvalue': 9.33,
#   'value': 6.39},
#  '60': {'hscode': '60',
#   'description': 'KNITTED OR CROCHETED FABRICS.',
#   'pvalue': 0.09,
#   'value': 0.02},
#  '61': {'hscode': '61',
#   'description': 'ARTICLES OF APPAREL AND CLOTHING ACCESSORIES, KNITTED OR CORCHETED.',
#   'pvalue': 31.520000000000003,
#   'value': 33.10999999999999},
#  '62': {'hscode': '62',
#   'description': 'ARTICLES OF APPAREL AND CLOTHING ACCESSORIES, NOT KNITTED OR CROCHETED.',
#   'pvalue': 176.28,
#   'value': 191.37999999999997},
#  '63': {'hscode': '63',
#   'description': 'OTHER MADE UP TEXTILE ARTICLES; SETS; WORN CLOTHING AND WORN TEXTILE ARTICLES; RAGS',
#   'pvalue': 47.7,
#   'value': 60.23},
#  '64': {'hscode': '64',
#   'description': 'FOOTWEAR, GAITERS AND THE LIKE; PARTS OF SUCH ARTICLES.',
#   'pvalue': 39.57,
#   'value': 37.080000000000005},
#  '65': {'hscode': '65',
#   'description': 'HEADGEAR AND PARTS THEREOF.',
#   'pvalue': 0.19,
#   'value': 0.15},
#  '66': {'hscode': '66',
#   'description': 'UMBRELLAS, SUN UMBRELLAS, WALKING-STICKS, SEAT-STICKS, WHIPS,RIDING-CROPS AND PARTS THEREOF.',
#   'pvalue': 0.0,
#   'value': 0.0},
#  '67': {'hscode': '67',
#   'description': 'PREPARED FEATHERS AND DOWN AND ARTICLES MADE OF FEATHERS OR OF DOWN; ARTIFICIAL FLOWERS; ARTICLES OF HUMAN HAIR.',
#   'pvalue': 0.02,
#   'value': 0.01},
#  '68': {'hscode': '68',
#   'description': 'ARTICLES OF STONE, PLASTER, CEMENT, ASBESTOS, MICA OR SIMILAR MATERIALS.',
#   'pvalue': 8.150000000000002,
#   'value': 9.1},
#  '69': {'hscode': '69',
#   'description': 'CERAMIC PRODUCTS.',
#   'pvalue': 12.629999999999999,
#   'value': 19.26},
#  '70': {'hscode': '70',
#   'description': 'GLASS AND GLASSWARE.',
#   'pvalue': 1.8700000000000003,
#   'value': 2.19},
#  '71': {'hscode': '71',
#   'description': 'NATURAL OR CULTURED PEARLS,PRECIOUS OR SEMIPRECIOUS STONES,PRE.METALS,CLAD WITH PRE.METAL AND ARTCLS THEREOF;IMIT.JEWLRY;COIN.',
#   'pvalue': 396.55,
#   'value': 420.61999999999995},
#  '72': {'hscode': '72',
#   'description': 'IRON AND STEEL',
#   'pvalue': 241.96000000000004,
#   'value': 208.26},
#  '73': {'hscode': '73',
#   'description': 'ARTICLES OF IRON OR STEEL',
#   'pvalue': 51.85000000000001,
#   'value': 45.769999999999996},
#  '74': {'hscode': '74',
#   'description': 'COPPER AND ARTICLES THEREOF.',
#   'pvalue': 4.960000000000001,
#   'value': 5.420000000000001},
#  '75': {'hscode': '75',
#   'description': 'NICKEL AND ARTICLES THEREOF.',
#   'pvalue': 1.2900000000000003,
#   'value': 1.79},
#  '76': {'hscode': '76',
#   'description': 'ALUMINIUM AND ARTICLES THEREOF.',
#   'pvalue': 180.28,
#   'value': 150.67000000000002},
#  '78': {'hscode': '78',
#   'description': 'LEAD AND ARTICLES THEREOF.',
#   'pvalue': 4.959999999999999,
#   'value': 4.979999999999999},
#  '79': {'hscode': '79',
#   'description': 'ZINC AND ARTICLES THEREOF.',
#   'pvalue': 10.079999999999998,
#   'value': 4.549999999999999},
#  '80': {'hscode': '80',
#   'description': 'TIN AND ARTICLES THEREOF.',
#   'pvalue': 0.0,
#   'value': 0.01},
#  '81': {'hscode': '81',
#   'description': 'OTHER BASE METALS; CERMETS; ARTICLES THEREOF.',
#   'pvalue': 1.5200000000000002,
#   'value': 1.4300000000000002},
#  '82': {'hscode': '82',
#   'description': 'TOOLS IMPLEMENTS, CUTLERY, SPOONS AND FORKS, OF BASE METAL; PARTS THEREOF OF BASE METAL.',
#   'pvalue': 5.86,
#   'value': 6.32},
#  '83': {'hscode': '83',
#   'description': 'MISCELLANEOUS ARTICLES OF BASE METAL.',
#   'pvalue': 2.31,
#   'value': 3.0900000000000003},
#  '84': {'hscode': '84',
#   'description': 'NUCLEAR REACTORS, BOILERS, MACHINERY AND MECHANICAL APPLIANCES; PARTS THEREOF.',
#   'pvalue': 423.06999999999994,
#   'value': 302.49},
#  '85': {'hscode': '85',
#   'description': 'ELECTRICAL MACHINERY AND EQUIPMENT AND PARTS THEREOF; SOUND RECORDERS AND REPRODUCERS, TELEVISION IMAGE AND SOUND RECORDERS AND REPRODUCERS,AND PARTS.',
#   'pvalue': 119.92000000000002,
#   'value': 112.71},
#  '86': {'hscode': '86',
#   'description': 'RAILWAY OR TRAMWAY LOCOMOTIVES, ROLLING-STOCK AND PARTS THEREOF; RAILWAY OR TRAMWAY TRACK FIXTURES AND FITTINGS AND PARTS THEREOF; MECHANICAL',
#   'pvalue': 0.13,
#   'value': 0.01},
#  '87': {'hscode': '87',
#   'description': 'VEHICLES OTHER THAN RAILWAY OR TRAMWAY ROLLING STOCK, AND PARTS AND ACCESSORIES THEREOF.',
#   'pvalue': 234.07000000000005,
#   'value': 236.01000000000005},
#  '88': {'hscode': '88',
#   'description': 'AIRCRAFT, SPACECRAFT, AND PARTS THEREOF.',
#   'pvalue': 11.81,
#   'value': 13.260000000000002},
#  '89': {'hscode': '89',
#   'description': 'SHIPS, BOATS AND FLOATING STRUCTURES.',
#   'pvalue': 0.01,
#   'value': 0},
#  '90': {'hscode': '90',
#   'description': 'OPTICAL, PHOTOGRAPHIC CINEMATOGRAPHIC MEASURING, CHECKING PRECISION, MEDICAL OR SURGICAL INST. AND APPARATUS PARTS AND ACCESSORIES THEREOF;',
#   'pvalue': 70.89999999999999,
#   'value': 67.86},
#  '91': {'hscode': '91',
#   'description': 'CLOCKS AND WATCHES AND PARTS THEREOF.',
#   'pvalue': 0.07999999999999999,
#   'value': 0.12000000000000001},
#  '92': {'hscode': '92',
#   'description': 'MUSICAL INSTRUMENTS; PARTS AND ACCESSORIES OF SUCH ARTICLES.',
#   'pvalue': 1.01,
#   'value': 1.3299999999999998},
#  '93': {'hscode': '93',
#   'description': 'ARMS AND AMMUNITION; PARTS AND ACCESSORIES THEREOF.',
#   'pvalue': 0.08,
#   'value': 0.01},
#  '94': {'hscode': '94',
#   'description': 'FURNITURE; BEDDING, MATTRESSES, MATTRESS SUPPORTS, CUSHIONS AND SIMILAR STUFFED FURNISHING; LAMPS AND LIGHTING FITTINGS NOT ELSEWHERE SPECIFIED OR INC',
#   'pvalue': 11.07,
#   'value': 10.63},
#  '95': {'hscode': '95',
#   'description': 'TOYS, GAMES AND SPORTS REQUISITES; PARTS AND ACCESSORIES THEREOF.',
#   'pvalue': 1.68,
#   'value': 2.3499999999999996},
#  '96': {'hscode': '96',
#   'description': 'MISCELLANEOUS MANUFACTURED ARTICLES.',
#   'pvalue': 4.500000000000001,
#   'value': 4.28},
#  '97': {'hscode': '97',
#   'description': "WORKS OF ART COLLECTORS' PIECES AND ANTIQUES.",
#   'pvalue': 0.39,
#   'value': 0.4800000000000001},
#  '98': {'hscode': '98',
#   'description': 'PROJECT GOODS; SOME SPECIAL USES.',
#   'pvalue': 0.32,
#   'value': 1.9800000000000004},
#  '99': {'hscode': '99',
#   'description': 'MISCELLANEOUS GOODS.',
#   'pvalue': 0.31,
#   'value': 0.0},
#  '': {'hscode': '',
#   'description': 'Total',
#   'pvalue': 4782.2,
#   'value': 4821.29}}

# %%
api.sum_data(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-311b5202a5fa> in <module>
# ----> 1 api.sum_data(data)
#
# ~/tta/web/india/commerce.py in sum_data(self, data)
#      74         output = {}
#      75         for records in data:
# ---> 76             for key, record in records.items():
#      77
#      78                 if record['hscode'] in output:
#
# AttributeError: 'str' object has no attribute 'items'

# %%
import pandas as pd
pd.set_option('display.max_rows', 5000)

# %%
df = pd.DataFrame.from_dict(output, orient='index')

# %%
df
